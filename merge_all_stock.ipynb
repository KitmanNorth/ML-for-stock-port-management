# %% [markdown]
# # Train set

# %%
import os
import glob
import pandas as pd
os.chdir("../ML-for-stock-port-management/labeled-stock")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
len(all_filenames)
# Out:
# 1187

# %%
# create csv file with header
df = pd.read_csv(all_filenames[0])
df = pd.DataFrame(columns = df.columns)
df.to_csv('../stock.csv', index=None)

# %%
for i in range(len(all_filenames)):
    df = pd.read_csv(all_filenames[i])
    df25 = df.loc[25:,]
    df25.to_csv('../stock.csv', mode='a', index=None, header=False)

# %%
df = pd.read_csv('../stock.csv')
df.head()
# Out:
#         Date Symbol  Open  High   Low  Last  ChangePercent    Volumn  \
# 0  7/25/2017  2S-W1  1.18  1.19  1.11  1.13          -4.24   1183679
# 1  7/26/2017  2S-W1  1.14  1.17  1.13  1.15           1.77   1034870
# 2  7/27/2017  2S-W1  1.15  1.17  1.14  1.15           0.00    497605
# 3  7/31/2017  2S-W1  1.16  1.25  1.16  1.18           2.61   2447900
# 4   8/2/2017  2S-W1  1.26  1.41  1.26  1.39          10.32  30356339
#
#       Money     Net5D  ...     SMA12     SMA26      MACD     MACD5    MACD10  \
# 0   1355820  53777140  ...  1.162500  1.387692 -0.211104 -0.211104 -0.211104
# 1   1187180  23603650  ...  1.164167  1.351923 -0.174979 -0.193041 -0.193041
# 2    573360  11764790  ...  1.166667  1.320769 -0.144017 -0.176700 -0.176700
# 3   2921900   6909320  ...  1.175833  1.293077 -0.108226 -0.159582 -0.159582
# 4  40814480  46852740  ...  1.196667  1.276154 -0.058177 -0.139301 -0.139301
#
#         Vol5        RSI       RSI5      Money5  Status
# ...

# %% [markdown]
# # Test set

# %%
import os
import glob
import pandas as pd
os.chdir("../ML-for-stock-port-management/labeled-stock-test")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
len(all_filenames)
# Out:
# 857

# %%
# create csv file with header
df = pd.read_csv(all_filenames[0])
df = pd.DataFrame(columns = df.columns)
df.to_csv('../stock_test.csv', index=None)

# %%
for i in range(len(all_filenames)):
    df = pd.read_csv(all_filenames[i])
    df25 = df.loc[25:,]
    df25.to_csv('../stock_test.csv', mode='a', index=None, header=False)

# %%
df = pd.read_csv('../stock_test.csv')
df.head()
# Out:
#         Date Symbol  Open  High   Low  Last  ChangePercent   Volumn    Money  \
# 0  8/15/2019     2S  2.38  2.42  2.32  2.40          -0.83   674938  1603770
# 1  8/16/2019     2S  2.40  2.42  2.36  2.40           0.00  1645800  3916890
# 2  8/19/2019     2S  2.44  2.50  2.44  2.48           3.33  1181982  2925840
# 3  8/20/2019     2S  2.48  2.48  2.40  2.42          -2.42   387100   944070
# 4  8/21/2019     2S  2.44  2.44  2.40  2.42           0.00   350024   845060
#
#       Net5D  ...     SMA12     SMA26      MACD     MACD5    MACD10       Vol5  \
# 0   9489440  ...  2.255000  2.260769  0.006225  0.002222  0.007067   792446.2
# 1  13034280  ...  2.265000  2.266154  0.009701  0.003860  0.006528  1087226.2
# 2  15728340  ...  2.281667  2.274615  0.022350  0.009296  0.007308  1302302.6
# 3  15825270  ...  2.300000  2.280769  0.027379  0.014991  0.008731  1303862.6
# 4  10235630  ...  2.316667  2.287692  0.035071  0.020145  0.011064   847968.8
#
# ...
