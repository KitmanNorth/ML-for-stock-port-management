# %%
import os
import glob
import pandas as pd
os.chdir("../ML-for-stock-port-management/Individual-Stock")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['2S-W1.csv',
#  '2S.csv',
#  '7UP-W2.csv',
#  '7UP.csv',
#  'A.csv',
#  'A5.csv',
#  'AAV.csv',
#  'ABC-W1.csv',
#  'ABC-W2.csv',
#  'ABC.csv',
#  'ABICO.csv',
#  'ABM.csv',
#  'ABPIF.csv',
#  'ACAP-W1.csv',
#  'ACAP-W2.csv',
#  'ACAP.csv',
#  'ACC-W1.csv',
#  'ACC.csv',
#  'ACD-W2.csv',
#  'ACD-W4.csv',
#  'ACD.csv',
#  'ACG.csv',
#  'ADB.csv',
#  'ADVANC.csv',
#  'AEC-W2.csv',
#  'AEC-W4.csv',
#  'AEC.csv',
#  'AEONTS.csv',
#  'AF.csv',
#  'AFC.csv',
#  'AGE.csv',
#  'AH.csv',
#  'AHC.csv',
#  'AI.csv',
#  'AIE.csv',
#  'AIMCG.csv',
#  'AIMIRT.csv',
#  'AIRA-W1.csv',
#  'AIRA-W2.csv',
#  'AIRA.csv',
#  'AIT.csv',
#  'AJ.csv',
#  'AJA-W1.csv',
#  'AJA.csv',
#  'AJD-W1.csv',
#  'AJD-W2.csv',
#  'AJD.csv',
#  'AJP-W1.csv',
#  'AJP.csv',
#  'AKP.csv',
#  'AKR-W1.csv',
#  'AKR.csv',
#  'ALL.csv',
#  'ALLA.csv',
#  'ALT-W1.csv',
#  'ALT.csv',
#  'ALUCON.csv',
#  'AMA.csv',
#  'AMANAH.csv',
#  'AMARIN.csv',
#  'AMATA.csv',
#  'AMATAR.csv',
#  'AMATAV.csv',
#  'AMC.csv',
#  'ANAN.csv',
#  'AOT.csv',
#  'AP.csv',
#  'APCO.csv',
#  'APCS.csv',
#  'APEX-W1.csv',
#  'APEX.csv',
#  'APURE-W2.csv',
#  'APURE.csv',
#  'APX.csv',
#  'AQ-W2.csv',
#  'AQ-W3.csv',
#  'AQ-W4.csv',
#  'AQ.csv',
#  'AQUA.csv',
#  'ARIN.csv',
#  'ARIP.csv',
#  'ARROW.csv',
#  'AS-W1.csv',
#  'AS.csv',
#  'ASAP.csv',
#  'ASEFA.csv',
#  'ASIA.csv',
#  'ASIAN.csv',
#  'ASIMAR.csv',
#  'ASK.csv',
#  'ASN.csv',
#  'ASP.csv',
#  'ATP30-W1.csv',
#  'ATP30.csv',
#  'AU.csv',
#  'AUCT.csv',
#  'AYUD-W1.csv',
#  'AYUD.csv',
#  'B-W3.csv',
#  'B-W4.csv',
#  'B-WORK.csv',
#  'B.csv',
#  'B52-W2.csv',
#  'B52.csv',
#  'BA.csv',
#  'BAFS.csv',
#  'BANPU-W3.csv',
#  'BANPU.csv',
#  'BAT-3K.csv',
#  'BAY.csv',
#  'BBL.csv',
#  'BCH.csv',
#  'BCP.csv',
#  'BCPG.csv',
#  'BCT.csv',
#  'BDMS.csv',
#  'BEAUTY.csv',
#  'BEC.csv',
#  'BECL.csv',
#  'BEM.csv',
#  'BFIT.csv',
#  'BGC.csv',
#  'BGH.csv',
#  'BGRIM.csv',
#  'BGT.csv',
#  'BH.csv',
#  'BIG.csv',
#  'BIGC.csv',
#  'BIZ.csv',
#  'BJC.csv',
#  'BJCHI.csv',
#  'BKD-W1.csv',
#  'BKD-W2.csv',
#  'BKD.csv',
#  'BKI.csv',
#  'BKKCP.csv',
#  'BLA.csv',
#  'BLAND-W3.csv',
#  'BLAND-W4.csv',
#  'BLAND.csv',
#  'BLISS.csv',
#  'BM-W1.csv',
#  'BM.csv',
#  'BMCL.csv',
#  'BOFFICE.csv',
#  'BOL.csv',
#  'BPP.csv',
#  'BR.csv',
#  'BROCK-W1.csv',
#  'BROCK.csv',
#  'BROOK-W4.csv',
#  'BROOK-W5.csv',
#  'BROOK.csv',
#  'BRR.csv',
#  'BRRGIF.csv',
#  'BSBM.csv',
#  'BSM-W1.csv',
#  'BSM-W2.csv',
#  'BSM.csv',
#  'BTC-W3.csv',
#  'BTC.csv',
#  'BTNC.csv',
#  'BTS-W3.csv',
#  'BTS-W4.csv',
#  'BTS.csv',
#  'BTSGIF.csv',
#  'BTW.csv',
#  'BUI.csv',
#  'BWG-W2.csv',
#  'BWG-W3.csv',
#  'BWG-W4.csv',
#  'BWG.csv',
#  'CAZ.csv',
#  'CBG.csv',
#  'CCET.csv',
#  'CCN-W1.csv',
#  'CCN.csv',
#  'CCP-W2.csv',
#  'CCP.csv',
#  'CEI.csv',
#  'CEN-W3.csv',
#  'CEN-W4.csv',
#  'CEN.csv',
#  'CENTEL.csv',
#  'CFRESH.csv',
#  'CGD-W3.csv',
#  'CGD-W4.csv',
#  'CGD.csv',
#  'CGH-W1.csv',
#  'CGH-W2.csv',
#  'CGH-W3.csv',
#  'CGH.csv',
#  'CGS.csv',
#  'CHARAN.csv',
#  'CHAYO.csv',
#  'CHEWA-W1.csv',
#  'CHEWA.csv',
#  'CHG.csv',
#  'CHO-W1.csv',
#  'CHO-W2.csv',
#  'CHO.csv',
#  'CHOTI.csv',
#  'CHOW.csv',
#  'CHUO.csv',
#  'CI-W1.csv',
#  'CI.csv',
#  'CIG-W5.csv',
#  'CIG-W6.csv',
#  'CIG-W7.csv',
#  'CIG.csv',
#  'CIMBT.csv',
#  'CITY.csv',
#  'CK.csv',
#  'CKP-W1.csv',
#  'CKP.csv',
#  'CM.csv',
#  'CMAN.csv',
#  'CMC.csv',
#  'CMO-W1.csv',
#  'CMO.csv',
#  'CMR.csv',
#  'CNS.csv',
#  'CNT.csv',
#  'COL.csv',
#  'COLOR-W1.csv',
#  'COLOR.csv',
#  'COM-7.csv',
#  'COMAN.csv',
#  'COTTO.csv',
#  'CPALL.csv',
#  'CPF.csv',
#  'CPH.csv',
#  'CPI-W1.csv',
#  'CPI.csv',
#  'CPL.csv',
#  'CPN.csv',
#  'CPNCG.csv',
#  'CPNREIT.csv',
#  'CPNRF.csv',
#  'CPR.csv',
#  'CPT.csv',
#  'CPTGF.csv',
#  'CRANE-W1.csv',
#  'CRANE.csv',
#  'CRD.csv',
#  'CRYSTAL.csv',
#  'CSC.csv',
#  'CSL.csv',
#  'CSP.csv',
#  'CSR.csv',
#  'CSS-W1.csv',
#  'CSS.csv',
#  'CTARAF.csv',
#  'CTW.csv',
#  'CWT-W2.csv',
#  'CWT-W3.csv',
#  'CWT-W4.csv',
#  'CWT.csv',
#  'CYBER-W1.csv',
#  'CYBER.csv',
#  'D.csv',
#  'DAII.csv',
#  'DCC-W1.csv',
#  'DCC.csv',
#  'DCON-W1.csv',
#  'DCON-W2.csv',
#  'DCON.csv',
#  'DCORP-W1.csv',
#  'DCORP.csv',
#  'DDD.csv',
#  'DELTA.csv',
#  'DEMCO-W6.csv',
#  'DEMCO.csv',
#  'DIF.csv',
#  'DIGI-W1.csv',
#  'DIGI-W2.csv',
#  'DIGI.csv',
#  'DIMET-W1.csv',
#  'DIMET-W2.csv',
#  'DIMET.csv',
#  'DNA-W1.csv',
#  'DNA.csv',
#  'DOD-W1.csv',
#  'DOD.csv',
#  'DOHOME.csv',
#  'DRACO.csv',
#  'DREIT.csv',
#  'DRT.csv',
#  'DSGT.csv',
#  'DTAC.csv',
#  'DTC.csv',
#  'DTCI.csv',
#  'DTCPF.csv',
#  'E-W1.csv',
#  'E-W2.csv',
#  'E-W3.csv',
#  'E-W4.csv',
#  'E.csv',
#  'EA.csv',
#  'EARTH-W3.csv',
#  'EARTH-W4.csv',
#  'EARTH.csv',
#  'EASON-W2.csv',
#  'EASON.csv',
#  'EASTW.csv',
#  'ECF-W1.csv',
#  'ECF-W2.csv',
#  'ECF-W3.csv',
#  'ECF.csv',
#  'ECL-W2.csv',
#  'ECL-W3.csv',
#  'ECL.csv',
#  'EE.csv',
#  'EFORL-W2.csv',
#  'EFORL-W3.csv',
#  'EFORL-W4.csv',
#  'EFORL.csv',
#  'EGATIF.csv',
#  'EGCO.csv',
#  'EIC-W1.csv',
#  'EIC-W2.csv',
#  'EIC-W3.csv',
#  'EIC-W4.csv',
#  'EIC.csv',
#  'EKH.csv',
#  'EMC-W4.csv',
#  'EMC-W5.csv',
#  'EMC-W6.csv',
#  'EMC.csv',
#  'EPCO-W2.csv',
#  'EPCO-W3.csv',
#  'EPCO.csv',
#  'EPG.csv',
#  'ERW.csv',
#  'ERWPF.csv',
#  'ESSO.csv',
#  'ESTAR.csv',
#  'ETE.csv',
#  'EVER-W2.csv',
#  'EVER-W3.csv',
#  'EVER.csv',
#  'F&D.csv',
#  'FANCY.csv',
#  'FC-W1.csv',
#  'FC-W2.csv',
#  'FC.csv',
#  'FE.csv',
#  'FER-W1.csv',
#  'FER-W2.csv',
#  'FER-W3.csv',
#  'FER.csv',
#  'FIRE.csv',
#  'FLOYD.csv',
#  'FMT.csv',
#  'FN.csv',
#  'FNS.csv',
#  'FOCUS-W2.csv',
#  'FOCUS.csv',
#  'FORTH.csv',
#  'FPI-W1.csv',
#  'FPI.csv',
#  'FPT.csv',
#  'FSMART.csv',
#  'FSS.csv',
#  'FTE.csv',
#  'FTREIT.csv',
#  'FUTUREPF.csv',
#  'FVC-W1.csv',
#  'FVC-W2.csv',
#  'FVC.csv',
#  'GAHREIT.csv',
#  'GBX.csv',
#  'GC.csv',
#  'GCAP.csv',
#  'GEL-W4.csv',
#  'GEL.csv',
#  'GENCO-W1.csv',
#  'GENCO.csv',
#  'GFPT.csv',
#  'GGC.csv',
#  'GIFT-W1.csv',
#  'GIFT.csv',
#  'GJS-W2.csv',
#  'GJS-W3.csv',
#  'GJS.csv',
#  'GL-W3.csv',
#  'GL-W4.csv',
#  'GL.csv',
#  'GLAND-W2.csv',
#  'GLAND-W3.csv',
#  'GLAND-W4.csv',
#  'GLAND.csv',
#  'GLANDRT.csv',
#  'GLOBAL.csv',
#  'GLOW.csv',
#  'GOLD.csv',
#  'GOLDPF.csv',
#  'GPI.csv',
#  'GPSC.csv',
#  'GRAMMY.csv',
#  'GRAND.csv',
#  'GREEN-W2.csv',
#  'GREEN-W4.csv',
#  'GREEN.csv',
#  'GSC.csv',
#  'GSTEEL.csv',
#  'GSTEL-W1.csv',
#  'GSTEL-W2.csv',
#  'GSTEL.csv',
#  'GTB.csv',
#  'GULF.csv',
#  'GUNKUL-W.csv',
#  'GUNKUL.csv',
#  'GVREIT.csv',
#  'GYT.csv',
#  'HANA.csv',
#  'HARN.csv',
#  'HEMRAJ.csv',
#  'HFT.csv',
#  'HMPRO.csv',
#  'HOTPOT.csv',
#  'HPF.csv',
#  'HPT-W1.csv',
#  'HPT.csv',
#  'HREIT.csv',
#  'HTC.csv',
#  'HTECH.csv',
#  'HUMAN.csv',
#  'HYDRO.csv',
#  'ICC.csv',
#  'ICHI.csv',
#  'ICN.csv',
#  'IEC-W2.csv',
#  'IEC.csv',
#  'IFEC-W1.csv',
#  'IFEC-W2.csv',
#  'IFEC.csv',
#  'IFS.csv',
#  'IHL-W1.csv',
#  'IHL.csv',
#  'III.csv',
#  'ILINK-W1.csv',
#  'ILINK.csv',
#  'ILM.csv',
#  'IMPACT.csv',
#  'INET.csv',
#  'INGRS.csv',
#  'INOX.csv',
#  'INSURE.csv',
#  'INTUCH.csv',
#  'IRC.csv',
#  'IRCP-W2.csv',
#  'IRCP.csv',
#  'IRPC.csv',
#  'IT.csv',
#  'ITD-W1.csv',
#  'ITD.csv',
#  'ITEL-W1.csv',
#  'ITEL.csv',
#  'IVL-W1.csv',
#  'IVL-W2.csv',
#  'IVL.csv',
#  'J-W1.csv',
#  'J.csv',
#  'JAS-W3.csv',
#  'JAS.csv',
#  'JASIF.csv',
#  'JCK-W4.csv',
#  'JCK-W5.csv',
#  'JCK.csv',
#  'JCKH.csv',
#  'JCT.csv',
#  'JKN-W1.csv',
#  'JKN.csv',
#  'JMART-W2.csv',
#  'JMART.csv',
#  'JMT-W1.csv',
#  'JMT-W2.csv',
#  'JMT.csv',
#  'JSP.csv',
#  'JTS.csv',
#  'JUBILE.csv',
#  'JUTHA.csv',
#  'JWD.csv',
#  'K.csv',
#  'KAMART.csv',
#  'KASET.csv',
#  'KBANK.csv',
#  'KBS.csv',
#  'KC.csv',
#  'KCAR.csv',
#  'KCE-W2.csv',
#  'KCE.csv',
#  'KCM.csv',
#  'KDH.csv',
#  'KGI.csv',
#  'KIAT-W1.csv',
#  'KIAT.csv',
#  'KKC.csv',
#  'KKP.csv',
#  'KOOL.csv',
#  'KPNPF.csv',
#  'KSL.csv',
#  'KTB.csv',
#  'KTC.csv',
#  'KTECH.csv',
#  'KTIS.csv',
#  'KTP.csv',
#  'KUMWEL.csv',
#  'KWC.csv',
#  'KWG.csv',
#  'KWM.csv',
#  'KYE.csv',
#  'L&E-W3.csv',
#  'L&E.csv',
#  'LALIN.csv',
#  'LANNA.csv',
#  'LDC.csv',
#  'LEE.csv',
#  'LH-W3.csv',
#  'LH.csv',
#  'LHBANK.csv',
#  'LHFG.csv',
#  'LHHOTEL.csv',
#  'LHK.csv',
#  'LHPF.csv',
#  'LHSC.csv',
#  'LIT-W1.csv',
#  'LIT.csv',
#  'LIVE-W2.csv',
#  'LIVE.csv',
#  'LOXLEY-W.csv',
#  'LOXLEY.csv',
#  'LPH.csv',
#  'LPN.csv',
#  'LRH.csv',
#  'LST.csv',
#  'LTX.csv',
#  'LUXF.csv',
#  'LVT.csv',
#  'M-AAA.csv',
#  'M-CHAI.csv',
#  'M-II.csv',
#  'M-PAT.csv',
#  'M-STOR.csv',
#  'M.csv',
#  'MACO-W1.csv',
#  'MACO-W2.csv',
#  'MACO.csv',
#  'MAJOR.csv',
#  'MAKRO.csv',
#  'MALEE.csv',
#  'MANRIN.csv',
#  'MATCH.csv',
#  'MATI.csv',
#  'MAX-W2.csv',
#  'MAX-W3.csv',
#  'MAX.csv',
#  'MBAX-W1.csv',
#  'MBAX.csv',
#  'MBK.csv',
#  'MBKET.csv',
#  'MC.csv',
#  'MCOT.csv',
#  'MCS.csv',
#  'MDX.csv',
#  'MEGA.csv',
#  'META-W2.csv',
#  'META-W3.csv',
#  'META-W4.csv',
#  'META.csv',
#  'METCO.csv',
#  'MFC-W1.csv',
#  'MFC.csv',
#  'MFEC.csv',
#  'MGT.csv',
#  'MIDA-W2.csv',
#  'MIDA.csv',
#  'MILL-W2.csv',
#  'MILL-W3.csv',
#  'MILL-W4.csv',
#  'MILL-W5.csv',
#  'MILL.csv',
#  'MINT-W5.csv',
#  'MINT-W6.csv',
#  'MINT.csv',
#  'MIPF.csv',
#  'MIT.csv',
#  'MITSIB.csv',
#  'MJD.csv',
#  'MJLF.csv',
#  'MK.csv',
#  'ML-W2.csv',
#  'ML.csv',
#  'MLINK-W1.csv',
#  'MLINK.csv',
#  'MM.csv',
#  'MNIT.csv',
#  'MNIT2.csv',
#  'MNRF.csv',
#  'MODERN.csv',
#  'MONO-W1.csv',
#  'MONO.csv',
#  'MONTRI.csv',
#  'MOONG-W1.csv',
#  'MOONG.csv',
#  'MORE.csv',
#  'MPG-W1.csv',
#  'MPG.csv',
#  'MPIC.csv',
#  'MSC.csv',
#  'MTC.csv',
#  'MTI.csv',
#  'MTLS.csv',
#  'MVP.csv',
#  'NBC-W1.csv',
#  'NBC.csv',
#  'NC.csv',
#  'NCH.csv',
#  'NCL-W1.csv',
#  'NCL-W2.csv',
#  'NCL-W3.csv',
#  'NCL.csv',
#  'NDR-W1.csv',
#  'NDR.csv',
#  'NEP-W2.csv',
#  'NEP-W3.csv',
#  'NEP.csv',
#  'NER.csv',
#  'NETBAY.csv',
#  'NEW.csv',
#  'NEWS-W2.csv',
#  'NEWS-W3.csv',
#  'NEWS-W4.csv',
#  'NEWS-W5.csv',
#  'NEWS-W6.csv',
#  'NEWS.csv',
#  'NEX.csv',
#  'NFC-W1.csv',
#  'NFC.csv',
#  'NINE-W1.csv',
#  'NINE.csv',
#  'NKI.csv',
#  'NMG-W3.csv',
#  'NMG.csv',
#  'NNCL-W2.csv',
#  'NNCL.csv',
#  'NOBLE.csv',
#  'NOK-W1.csv',
#  'NOK.csv',
#  'NPARK-W1.csv',
#  'NPARK.csv',
#  'NPK.csv',
#  'NPP-W1.csv',
#  'NPP-W2.csv',
#  'NPP-W3.csv',
#  'NPP.csv',
#  'NPPG-W3.csv',
#  'NPPG-W4.csv',
#  'NPPG.csv',
#  'NSI.csv',
#  'NTV.csv',
#  'NUSA-W1.csv',
#  'NUSA-W2.csv',
#  'NUSA-W3.csv',
#  'NUSA.csv',
#  'NVD-W1.csv',
#  'NVD.csv',
#  'NWR.csv',
#  'NYT.csv',
#  'OCC.csv',
#  'OCEAN-W1.csv',
#  'OCEAN-W2.csv',
#  'OCEAN-W3.csv',
#  'OCEAN.csv',
#  'OFM.csv',
#  'OGC.csv',
#  'OHTL.csv',
#  'OISHI.csv',
#  'ORI-W1.csv',
#  'ORI.csv',
#  'OSP.csv',
#  'OTO.csv',
#  'PACE-W1.csv',
#  'PACE-W2.csv',
#  'PACE.csv',
#  'PAE-W1.csv',
#  'PAE.csv',
#  'PAF.csv',
#  'PAP.csv',
#  'PATO.csv',
#  'PB.csv',
#  'PCA.csv',
#  'PCSGH.csv',
#  'PDG.csv',
#  'PDI-W1.csv',
#  'PDI.csv',
#  'PDJ-W2.csv',
#  'PDJ-W3.csv',
#  'PDJ-W4.csv',
#  'PDJ.csv',
#  'PE.csv',
#  'PERM-W1.csv',
#  'PERM.csv',
#  'PF-W3.csv',
#  'PF.csv',
#  'PG.csv',
#  'PHOL-W1.csv',
#  'PHOL.csv',
#  'PICO.csv',
#  'PIMO-W1.csv',
#  'PIMO.csv',
#  'PJW.csv',
#  'PK.csv',
#  'PL-W1.csv',
#  'PL.csv',
#  'PLANB.csv',
#  'PLANET.csv',
#  'PLAT.csv',
#  'PLE-W2.csv',
#  'PLE-W3.csv',
#  'PLE.csv',
#  'PM.csv',
#  'PMTA.csv',
#  'POLAR-W2.csv',
#  'POLAR-W3.csv',
#  'POLAR.csv',
#  'POPF.csv',
#  'PORT-W1.csv',
#  'PORT.csv',
#  'POST.csv',
#  'PPF.csv',
#  'PPM-W1.csv',
#  'PPM.csv',
#  'PPP.csv',
#  'PPPM.csv',
#  'PPS-W1.csv',
#  'PPS.csv',
#  'PR.csv',
#  'PR9.csv',
#  'PRAKIT.csv',
#  'PRANDA.csv',
#  'PREB.csv',
#  'PRECHA.csv',
#  'PRG.csv',
#  'PRIME-W1.csv',
#  'PRIME-W2.csv',
#  'PRIME.csv',
#  'PRIN.csv',
#  'PRINC-W1.csv',
#  'PRINC.csv',
#  'PRM.csv',
#  'PRO.csv',
#  'PROUD-W2.csv',
#  'PROUD.csv',
#  'PS.csv',
#  'PSH.csv',
#  'PSL-W1.csv',
#  'PSL.csv',
#  'PSTC-W1.csv',
#  'PSTC.csv',
#  'PT.csv',
#  'PTG.csv',
#  'PTL.csv',
#  'PTT.csv',
#  'PTTEP.csv',
#  'PTTGC.csv',
#  'PYLON-W1.csv',
#  'PYLON.csv',
#  'Q-CON.csv',
#  'QH.csv',
#  'QHHR.csv',
#  'QHOP.csv',
#  'QHPF.csv',
#  'QLT.csv',
#  'QTC-W1.csv',
#  'QTC.csv',
#  'RAM.csv',
#  'RATCH.csv',
#  'RCI-W1.csv',
#  'RCI.csv',
#  'RCL.csv',
#  'RICH-W1.csv',
#  'RICH.csv',
#  'RICHY-W1.csv',
#  'RICHY-W2.csv',
#  'RICHY.csv',
#  'RJH.csv',
#  'RML-W3.csv',
#  'RML-W4.csv',
#  'RML.csv',
#  'ROBINS.csv',
#  'ROCK.csv',
#  'ROH.csv',
#  'ROJNA-W3.csv',
#  'ROJNA.csv',
#  'RP.csv',
#  'RPC.csv',
#  'RPH.csv',
#  'RS-W3.csv',
#  'RS.csv',
#  'RSP.csv',
#  'RWI-W1.csv',
#  'RWI.csv',
#  'S & J.csv',
#  'S-W1.csv',
#  'S.csv',
#  'S11.csv',
#  'SAAM.csv',
#  'SABINA.csv',
#  'SALEE.csv',
#  'SAM.csv',
#  'SAMART-W.csv',
#  'SAMART-W2.csv',
#  'SAMART.csv',
#  'SAMCO.csv',
#  'SAMTEL.csv',
#  'SANKO-W1.csv',
#  'SANKO.csv',
#  'SAPPE.csv',
#  'SAT.csv',
#  'SAUCE.csv',
#  'SAWAD-W1.csv',
#  'SAWAD.csv',
#  'SAWANG.csv',
#  'SBPF.csv',
#  'SC.csv',
#  'SCB.csv',
#  'SCBLIF.csv',
#  'SCC.csv',
#  'SCCC.csv',
#  'SCG.csv',
#  'SCI.csv',
#  'SCN.csv',
#  'SCP.csv',
#  'SDC-W1.csv',
#  'SDC.csv',
#  'SE-ED.csv',
#  'SE.csv',
#  'SEAFCO.csv',
#  'SEAOIL-W.csv',
#  'SEAOIL.csv',
#  'SEG.csv',
#  'SELIC.csv',
#  'SENA.csv',
#  'SF.csv',
#  'SFP.csv',
#  'SGF.csv',
#  'SGP.csv',
#  'SHANG.csv',
#  'SHREIT.csv',
#  'SIAM.csv',
#  'SIM.csv',
#  'SIMAT-W2.csv',
#  'SIMAT-W3.csv',
#  'SIMAT-W4.csv',
#  'SIMAT.csv',
#  'SINGER-W1.csv',
#  'SINGER-W2.csv',
#  'SINGER.csv',
#  'SIRI-W2.csv',
#  'SIRI.csv',
#  'SIRIP.csv',
#  'SIS.csv',
#  'SISB.csv',
#  'SITHAI.csv',
#  'SKE.csv',
#  'SKN.csv',
#  'SKR.csv',
#  'SKY-W1.csv',
#  'SKY.csv',
#  'SLC-W1.csv',
#  'SLC-W2.csv',
#  'SLC-W3.csv',
#  'SLC-W4.csv',
#  'SLC.csv',
#  'SLP.csv',
#  'SMART-W1.csv',
#  'SMART.csv',
#  'SMG.csv',
#  'SMIT.csv',
#  'SMK.csv',
#  'SMM-W3.csv',
#  'SMM-W4.csv',
#  'SMM.csv',
#  'SMPC.csv',
#  'SMT-W1.csv',
#  'SMT-W2.csv',
#  'SMT.csv',
#  'SNC.csv',
#  'SNP.csv',
#  'SOLAR.csv',
#  'SONIC.csv',
#  'SORKON.csv',
#  'SPA.csv',
#  'SPACK.csv',
#  'SPALI-W4.csv',
#  'SPALI.csv',
#  'SPC.csv',
#  'SPCG.csv',
#  'SPF.csv',
#  'SPG.csv',
#  'SPI.csv',
#  'SPORT-W3.csv',
#  'SPORT-W5.csv',
#  'SPORT-W6.csv',
#  'SPORT-W7.csv',
#  'SPORT.csv',
#  'SPPT.csv',
#  'SPRC.csv',
#  'SPRIME.csv',
#  'SPVI.csv',
#  'SPWPF.csv',
#  'SQ.csv',
#  'SR.csv',
#  'SRICHA.csv',
#  'SRIPANWA.csv',
#  'SSC.csv',
#  'SSF.csv',
#  'SSI.csv',
#  'SSP.csv',
#  'SSPF.csv',
#  'SSSC.csv',
#  'SST-W2.csv',
#  'SST.csv',
#  'SSTPF.csv',
#  'SSTRT.csv',
#  'SSTSS.csv',
#  'STA.csv',
#  'STANLY.csv',
#  'STAR-W2.csv',
#  'STAR-W3.csv',
#  'STAR.csv',
#  'STARK.csv',
#  'STEC.csv',
#  'STHAI.csv',
#  'STI.csv',
#  'STPI.csv',
#  'SUC.csv',
#  'SUN.csv',
#  'SUPER-W1.csv',
#  'SUPER-W2.csv',
#  'SUPER-W3.csv',
#  'SUPER-W4.csv',
#  'SUPER.csv',
#  'SUSCO-W1.csv',
#  'SUSCO.csv',
#  'SUTHA.csv',
#  'SVH.csv',
#  'SVI-W3.csv',
#  'SVI.csv',
#  'SVOA.csv',
#  'SWC-W1.csv',
#  'SWC.csv',
#  'SYMC.csv',
#  'SYNEX.csv',
#  'SYNTEC.csv',
#  'T-W3.csv',
#  'T.csv',
#  'TACC.csv',
#  'TAE.csv',
#  'TAKUNI-W.csv',
#  'TAKUNI.csv',
#  'TAPAC-W2.csv',
#  'TAPAC-W3.csv',
#  'TAPAC.csv',
#  'TASCO.csv',
#  'TBSP.csv',
#  'TC.csv',
#  'TCAP.csv',
#  'TCB.csv',
#  'TCC-W2.csv',
#  'TCC-W3.csv',
#  'TCC-W4.csv',
#  'TCC-W5.csv',
#  'TCC.csv',
#  'TCCC.csv',
#  'TCIF.csv',
#  'TCJ-W1.csv',
#  'TCJ-W2.csv',
#  'TCJ.csv',
#  'TCMC-W1.csv',
#  'TCMC-W2.csv',
#  'TCMC.csv',
#  'TCOAT.csv',
#  'TEAM.csv',
#  'TEAMG.csv',
#  'TF.csv',
#  'TFD-W2.csv',
#  'TFD-W3.csv',
#  'TFD-W4.csv',
#  'TFD-W5.csv',
#  'TFD.csv',
#  'TFFIF.csv',
#  'TFG-W1.csv',
#  'TFG-W2.csv',
#  'TFG.csv',
#  'TFI.csv',
#  'TFMAMA.csv',
#  'TFUND.csv',
#  ...]

# %%
# create csv file with header
df = pd.read_csv(all_filenames[0])
df = pd.DataFrame(columns = df.columns)
df.to_csv('../stock.csv', index=None)

# %%
for i in range(len(all_filenames)):
    df = pd.read_csv(all_filenames[i])
    df25 = df.loc[25:,]
    df25.to_csv('../stock.csv', mode='a', index=None, header=False)

# %%
df = pd.read_csv('../stock.csv')
df.head()
# Out:
#         Date Symbol  Open  High   Low  Last  ChangePercent    Volumn  \
# 0  7/25/2017  2S-W1  1.18  1.19  1.11  1.13          -4.24   1183679
# 1  7/26/2017  2S-W1  1.14  1.17  1.13  1.15           1.77   1034870
# 2  7/27/2017  2S-W1  1.15  1.17  1.14  1.15           0.00    497605
# 3  7/31/2017  2S-W1  1.16  1.25  1.16  1.18           2.61   2447900
# 4   8/2/2017  2S-W1  1.26  1.41  1.26  1.39          10.32  30356339
#
#       Money     Net5D  ...     SMA12     SMA26      MACD     MACD5       Vol5  \
# 0   1355820  53777140  ...  1.162500  1.387692 -0.211104 -0.211104  8700893.0
# 1   1187180  23603650  ...  1.164167  1.351923 -0.174979 -0.193041  3818884.6
# 2    573360  11764790  ...  1.166667  1.320769 -0.144017 -0.176700  1954325.8
# 3   2921900   6909320  ...  1.175833  1.293077 -0.108226 -0.159582  1181050.6
# 4  40814480  46852740  ...  1.196667  1.276154 -0.058177 -0.139301  7104078.6
#
#          RSI       RSI5      Money5  Status    MACD10
# 0  21.428571  22.857143  10755428.0     0.0 -0.211104
# 1  28.571429  22.857143   4720730.0     0.0 -0.193041
# 2  28.571429  24.285714   2352958.0     0.0 -0.176700
# 3  35.714286  27.142857   1381864.0     2.0 -0.159582
# 4  42.857143  31.428571   9370548.0     2.0 -0.139301
#
# [5 rows x 23 columns]
